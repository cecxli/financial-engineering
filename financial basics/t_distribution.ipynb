# %%
import pandas as pd
import numpy as np
import plotly.express as px
from scipy.stats import t, norm
from plotly.subplots import make_subplots

# %%
full_df = pd.read_csv('../../data/full_data/full_df.csv')
full_df.head()
# Out:
#          Date      Open      High       Low     Close  Adj Close     Volume  \
# 0  2009-12-31  7.611786  7.619643  7.520000  7.526071   6.444381  352410800
# 1  2010-01-04  7.622500  7.660714  7.585000  7.643214   6.544686  493729600
# 2  2010-01-05  7.664286  7.699643  7.616071  7.656429   6.556002  601904800
# 3  2010-01-06  7.656429  7.686786  7.526786  7.534643   6.451719  552160000
# 4  2010-01-07  7.562500  7.571429  7.466071  7.520714   6.439793  477131200
#
#    Name
# 0  AAPL
# 1  AAPL
# 2  AAPL
# 3  AAPL
# 4  AAPL

# %%
import datetime

# %%
aapl_df = full_df[(full_df['Name'] == 'AAPL') &\
     (full_df['Date'] >= '2015-01-01')].copy()

aapl_df.tail()
# Out:
#             Date        Open        High         Low       Close   Adj Close  \
# 3050  2022-02-11  172.330002  173.080002  168.039993  168.639999  168.639999
# 3051  2022-02-14  167.369995  169.580002  166.559998  168.880005  168.880005
# 3052  2022-02-15  170.970001  172.949997  170.250000  172.789993  172.789993
# 3053  2022-02-16  171.850006  173.339996  170.050003  172.550003  172.550003
# 3054  2022-02-17  171.850006  171.720001  170.750000  171.514999  171.514999
#
#         Volume  Name
# 3050  98566000  AAPL
# 3051  86062800  AAPL
# 3052  64286300  AAPL
# 3053  61067300  AAPL
# 3054   5299200  AAPL

# %%
aapl_df['log_return'] = np.log(aapl_df['Adj Close']) - np.log(aapl_df['Adj Close'].shift(1))
aapl_df['pct change'] = aapl_df['Adj Close'].pct_change()
aapl_df.head()
# Out:
#             Date       Open       High        Low      Close  Adj Close  \
# 1259  2015-01-02  27.847500  27.860001  26.837500  27.332500  24.714510
# 1260  2015-01-05  27.072500  27.162500  26.352501  26.562500  24.018259
# 1261  2015-01-06  26.635000  26.857500  26.157499  26.565001  24.020523
# 1262  2015-01-07  26.799999  27.049999  26.674999  26.937500  24.357342
# 1263  2015-01-08  27.307501  28.037500  27.174999  27.972500  25.293205
#
#          Volume  Name  log_return  pct change
# 1259  212818400  AAPL         NaN         NaN
# 1260  257142000  AAPL   -0.028576   -0.028172
# 1261  263188400  AAPL    0.000094    0.000094
# 1262  160423600  AAPL    0.013925    0.014022
# 1263  237458000  AAPL    0.037702    0.038422

# %%
fig = px.histogram(aapl_df['log_return'])
fig.update_layout(title = 'Distribution of log retutn values',
                template = 'plotly_dark', 
                width=1000, 
                height=500)
fig.show()

# %%
aapl_df.shape
# Out:
# (1796, 10)

# %%
x_ls = np.linspace(
    aapl_df['log_return'].min(),
    aapl_df['log_return'].max(),
    100
)
params = t.fit(aapl_df['log_return'].dropna())

# %%
df, loc, scale = params

# %%
y_ls = t.pdf(x_ls, df, loc, scale)

# %%
import plotly.graph_objects as go
fig = go.Figure()
fig.add_trace(go.Histogram(x =aapl_df['log_return'], nbinsx = 1000))
fig.add_trace(go.Scatter(x = x_ls, y = y_ls, mode = 'lines'))
fig.update_layout(template = 'plotly_dark', 
                width=1000, 
                height=500)
fig.show()
